# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from classipy import DataFrameTransformer

# %%
df = pd.read_csv('../raw_data/kaggle_housing.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import RandomizedSearchCV

# %%
df_transformed = DataFrameTransformer('kaggle_housing','train_dataset').fit_transform(df)
# Out:
# fit called
# transform called
# Processing DataFrame: kaggle_housing train_dataset

# %%
df_transformed.head()
# Out:
#      dataset_name     table_name  ...        kurt shapiro_wilk_test
# 0  kaggle_housing  train_dataset  ...   -1.189391      9.832541e-17
# 1  kaggle_housing  train_dataset  ...    1.691031      7.235487e-33
# 2  kaggle_housing  train_dataset  ...    0.000000      0.000000e+00
# 3  kaggle_housing  train_dataset  ...   13.601222      1.000000e+00
# 4  kaggle_housing  train_dataset  ...  270.621470      0.000000e+00
#
# [5 rows x 14 columns]
